# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Dataset

# %% [markdown]
# * *Load the dataset into a Pandas DataFrame.*

# %%
new_data = pd.read_csv("C:\\Users\\GEETHU\\Desktop\\Data Science\\melb_data.csv")
new_data
# Out:
#               Suburb           Address  Rooms Type    Price Method   SellerG  \
# 0         Abbotsford      85 Turner St      2    h  1480000      S    Biggin
# 1         Abbotsford   25 Bloomburg St      2    h  1035000      S    Biggin
# 2         Abbotsford      5 Charles St      3    h  1465000     SP    Biggin
# 3         Abbotsford  40 Federation La      3    h   850000     PI    Biggin
# 4         Abbotsford       55a Park St      4    h  1600000     VB    Nelson
# ...              ...               ...    ...  ...      ...    ...       ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000      S     Barry
# 13576   Williamstown     77 Merrett Dr      3    h  1031000     SP  Williams
# 13577   Williamstown       83 Power St      3    h  1170000      S     Raine
# 13578   Williamstown      96 Verdon St      4    h  2500000     PI   Sweeney
# 13579     Yarraville        6 Agnes St      4    h  1285000     SP   Village
#
# ...

# %% [markdown]
# * *Display the first few rows of the data*

# %%
new_data.head()
# Out:
#        Suburb           Address  Rooms Type    Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000     VB  Nelson
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03-12-2016       2.5      3067  ...         1  1.0       202           NaN
# 1  04-02-2016       2.5      3067  ...         1  0.0       156          79.0
# 2  04-03-2017       2.5      3067  ...         2  0.0       134         150.0
# 3  04-03-2017       2.5      3067  ...         2  1.0        94           NaN
# 4  04-06-2016       2.5      3067  ...         1  2.0       120         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %% [markdown]
# * *Display the last few rows of the data*

# %%
new_data.tail()
# Out:
#               Suburb        Address  Rooms Type    Price Method   SellerG  \
# 13575  Wheelers Hill   12 Strada Cr      4    h  1245000      S     Barry
# 13576   Williamstown  77 Merrett Dr      3    h  1031000     SP  Williams
# 13577   Williamstown    83 Power St      3    h  1170000      S     Raine
# 13578   Williamstown   96 Verdon St      4    h  2500000     PI   Sweeney
# 13579     Yarraville     6 Agnes St      4    h  1285000     SP   Village
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 13575  26-08-2017      16.7      3150  ...         2  2.0       652
# 13576  26-08-2017       6.8      3016  ...         2  2.0       333
# 13577  26-08-2017       6.8      3016  ...         2  4.0       436
# 13578  26-08-2017       6.8      3016  ...         1  5.0       866
# 13579  26-08-2017       6.3      3013  ...         1  1.0       362
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# ...

# %% [markdown]
# # Basic information about the data

# %% [markdown]
# * *Get information about the DataFrame , including data types and missing values*

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  int64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  int64
#  10  Bedroom2       13580 non-null  int64
#  11  Bathroom       13580 non-null  int64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  int64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
# ...

# %%
new_data.shape
# Out:
# (13580, 21)

# %% [markdown]
# -- DataFrame contains 13580, rows and 21 columns

# %% [markdown]
# * *Describe the data*

# %%
new_data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %% [markdown]
# # Getting the statistical values of the data

# %% [markdown]
# * *Mean*

# %%
new_data.mean()
# Out:
# Rooms            2.937997e+00
# Price            1.075684e+06
# Distance         1.013778e+01
# Postcode         3.105302e+03
# Bedroom2         2.914728e+00
# Bathroom         1.534242e+00
# Car              1.610075e+00
# Landsize         5.584161e+02
# BuildingArea     1.519676e+02
# YearBuilt        1.964684e+03
# Lattitude       -3.780920e+01
# Longtitude       1.449952e+02
# Propertycount    7.454417e+03
# dtype: float64

# %% [markdown]
# * *Median*

# %%
new_data.median()
# Out:
# Rooms                 3.000000
# Price            903000.000000
# Distance              9.200000
# Postcode           3084.000000
# Bedroom2              3.000000
# Bathroom              1.000000
# Car                   2.000000
# Landsize            440.000000
# BuildingArea        126.000000
# YearBuilt          1970.000000
# Lattitude           -37.802355
# Longtitude          145.000100
# Propertycount      6555.000000
# dtype: float64

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# * *Duplicate values*

# %%
new_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# * *Null values*

# %%
new_data.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %% [markdown]
# * *Replace null value with mean value*

# %%
new_data['BuildingArea'].fillna(new_data['BuildingArea'].mean(),inplace=True)
new_data['YearBuilt'].fillna(new_data['YearBuilt'].mean(),inplace=True)


new_data.head()
# Out:
#        Suburb           Address  Rooms Type    Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000     VB  Nelson
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03-12-2016       2.5      3067  ...         1  1.0       202     151.96765
# 1  04-02-2016       2.5      3067  ...         1  0.0       156      79.00000
# 2  04-03-2017       2.5      3067  ...         2  0.0       134     150.00000
# 3  04-03-2017       2.5      3067  ...         2  1.0        94     151.96765
# 4  04-06-2016       2.5      3067  ...         1  2.0       120     142.00000
#
#      YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
print(new_data.isnull().sum())
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea        0
# YearBuilt           0
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
new_data.duplicated().sum()
# Out:
# 0

# %%
new_data.count()
# Out:
# Suburb           13580
# Address          13580
# Rooms            13580
# Type             13580
# Price            13580
# Method           13580
# SellerG          13580
# Date             13580
# Distance         13580
# Postcode         13580
# Bedroom2         13580
# Bathroom         13580
# Car              13518
# Landsize         13580
# BuildingArea     13580
# YearBuilt        13580
# CouncilArea      12211
# Lattitude        13580
# Longtitude       13580
# Regionname       13580
# Propertycount    13580
# dtype: int64

# %% [markdown]
# * *Date converting from string to date format*

# %%
new_data['Date'] = pd.to_datetime(new_data['Date'], format='%d-%m-%Y')
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  int64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  datetime64[ns]
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  int64
#  10  Bedroom2       13580 non-null  int64
#  11  Bathroom       13580 non-null  int64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  int64
#  14  BuildingArea   13580 non-null  float64
#  15  YearBuilt      13580 non-null  float64
#  16  CouncilArea    12211 non-null  object
# ...

# %% [markdown]
# * *Correlation*

# %%
new_data.corr()
# Out:
#                   Rooms     Price  Distance  Postcode  Bedroom2  Bathroom  \
# Rooms          1.000000  0.496634  0.294203  0.055303  0.944190  0.592934
# Price          0.496634  1.000000 -0.162522  0.107867  0.475951  0.467038
# Distance       0.294203 -0.162522  1.000000  0.431514  0.295927  0.127155
# Postcode       0.055303  0.107867  0.431514  1.000000  0.060584  0.113664
# Bedroom2       0.944190  0.475951  0.295927  0.060584  1.000000  0.584685
# Bathroom       0.592934  0.467038  0.127155  0.113664  0.584685  1.000000
# Car            0.408483  0.238979  0.262994  0.050289  0.405325  0.322246
# Landsize       0.025678  0.037507  0.025004  0.024558  0.025646  0.037130
# BuildingArea   0.091373  0.069570  0.073990  0.040714  0.089102  0.084462
# YearBuilt     -0.052112 -0.262144  0.193183  0.025406 -0.041894  0.120910
# Lattitude      0.015948 -0.212934 -0.130723 -0.406104  0.015925 -0.070594
# Longtitude     0.100771  0.203656  0.239425  0.445357  0.102238  0.118971
# ...

# %% [markdown]
# # Conditional Operations

# %% [markdown]
# * *Filtering data where  Price are greater than 1500000 , Landsize is greater than 200*

# %%
max_building_area=new_data["BuildingArea"].unique().max()
filtered_data=new_data[(new_data["Price"]>=1500000)&(new_data["Landsize"]>=200)]
filtered_data.head()
# Out:
#          Suburb               Address  Rooms Type    Price Method   SellerG  \
# 6    Abbotsford          124 Yarra St      3    h  1876000      S    Nelson
# 7    Abbotsford         98 Charles St      2    h  1636000      S    Nelson
# 80  Albert Park  112 Beaconsfield Pde      3    h  2850000     PI    Buxton
# 86  Albert Park           4a Mills St      3    t  1550000     VB  Marshall
# 89  Albert Park          3 Herbert St      3    h  1800000     VB    Cayzer
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 6  2016-05-07       2.5      3067  ...         2  0.0       245     210.00000
# 7  2016-10-08       2.5      3067  ...         1  2.0       256     107.00000
# 80 2017-03-04       3.3      3206  ...         2  0.0       211     198.00000
# 86 2016-11-07       3.3      3206  ...         2  2.0       718     151.96765
# 89 2016-09-10       3.3      3206  ...         1  1.0       253     151.96765
#
# ...

# %% [markdown]
# * *Filtering data where Price less than 1500000 or Regionname is Southern Metropolitan*

# %%
data = new_data[(new_data['Price']<1500000)|(new_data['Regionname']=='Southern Metropolitan')]
data.head()
# Out:
#        Suburb           Address  Rooms Type    Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000     PI  Biggin
# 5  Abbotsford    129 Charles St      2    h   941000      S  Jellis
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0 2016-12-03       2.5      3067  ...         1  1.0       202     151.96765
# 1 2016-02-04       2.5      3067  ...         1  0.0       156      79.00000
# 2 2017-03-04       2.5      3067  ...         2  0.0       134     150.00000
# 3 2017-03-04       2.5      3067  ...         2  1.0        94     151.96765
# 5 2016-05-07       2.5      3067  ...         1  0.0       181     151.96765
#
#      YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %% [markdown]
# * *price less than 100000*

# %%
new_data[(new_data['Price']<100000)]
# Out:
#          Suburb           Address  Rooms Type  Price Method  SellerG  \
# 2652  Footscray  202/51 Gordon St      1    u  85000     PI  Burnham
#
#            Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 2652 2016-09-03       6.4      3011  ...         1  0.0         0
#
#       BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 2652     151.96765     2007.0  Maribyrnong  -37.7911      144.89
#
#                 Regionname Propertycount
# 2652  Western Metropolitan          7570
#
# [1 rows x 21 columns]

# %% [markdown]
# * *Assigning a category 'Good' for Parking Space greater than 1, 'Bad' otherwise*

# %%
new_data['Parking_space']=np.where(new_data["Car"]>1,'Good','Bad')
new_data.head()
# Out:
#        Suburb           Address  Rooms Type    Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000     VB  Nelson
#
#         Date  Distance  Postcode  ...  Car  Landsize  BuildingArea  \
# 0 2016-12-03       2.5      3067  ...  1.0       202     151.96765
# 1 2016-02-04       2.5      3067  ...  0.0       156      79.00000
# 2 2017-03-04       2.5      3067  ...  0.0       134     150.00000
# 3 2017-03-04       2.5      3067  ...  1.0        94     151.96765
# 4 2016-06-04       2.5      3067  ...  2.0       120     142.00000
#
#      YearBuilt  CouncilArea  Lattitude Longtitude             Regionname  \
# 0  1964.684217        Yarra   -37.7996   144.9984  Northern Metropolitan
# ...

# %% [markdown]
# * *Which regionname has highest count?*

# %%
region_count = new_data["Regionname"].value_counts()
plt.figure(figsize=(20,8))
region_count.plot(kind='bar', color='#00ffe8', edgecolor='black')
plt.xlabel('Region Name')
plt.ylabel('Count')
plt.title('Count of Region')
plt.show()

# %% [markdown]
# # Detecting Outliers

# %% [markdown]
# * *Boxplot for Price*

# %%
sns.boxplot(x=new_data['Price'])
# Out:
# <Axes: xlabel='Price'>

# %% [markdown]
# * *In which month we have best sales?*

# %%
new_data["Month"]=new_data["Date"].dt.month_name()
new_data.head()
# Out:
#        Suburb           Address  Rooms Type    Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000     VB  Nelson
#
#         Date  Distance  Postcode  ...  Landsize  BuildingArea    YearBuilt  \
# 0 2016-12-03       2.5      3067  ...       202     151.96765  1964.684217
# 1 2016-02-04       2.5      3067  ...       156      79.00000  1900.000000
# 2 2017-03-04       2.5      3067  ...       134     150.00000  1900.000000
# 3 2017-03-04       2.5      3067  ...        94     151.96765  1964.684217
# 4 2016-06-04       2.5      3067  ...       120     142.00000  2014.000000
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %%
real_estate_sold = new_data[['Month', 'SellerG']].groupby('Month').count()
real_estate_sold
# Out:
#            SellerG
# Month
# April          949
# August        1550
# December       607
# February       443
# January          2
# July          1982
# June          1830
# March          678
# May           2029
# November      1114
# October        551
# September     1845

# %%
real_estate_sold[real_estate_sold['SellerG']==real_estate_sold['SellerG'].max()]
# Out:
#        SellerG
# Month
# May       2029

# %% [markdown]
# * *In which month does least sales happened?*

# %%
real_estate_sold[real_estate_sold['SellerG']==real_estate_sold['SellerG'].min()]
# Out:
#          SellerG
# Month
# January        2

# %% [markdown]
# * *Which Type sells more?*

# %%
Regionname = new_data['Type'].unique()
Regionname
# Out:
# array(['h', 'u', 't'], dtype=object)

# %%
new_data.Type.value_counts()
sns.countplot(data=new_data,y="Type",palette="rocket")
plt.title("Count of data with rooms")
plt.ylabel("Rooms")
plt.xlabel("Count")
# Out:
# Text(0.5, 0, 'Count')

# %%
new_data.groupby('Type').describe()['YearBuilt'].T
# Out:
# Type             h            t            u
# count  9449.000000  1114.000000  3017.000000
# mean   1958.615718  1988.148873  1975.026152
# std      29.264288    23.221512    21.718653
# min    1196.000000  1860.000000  1830.000000
# 25%    1950.000000  1964.684217  1964.684217
# 50%    1964.684217  1998.000000  1970.000000
# 75%    1964.684217  2009.000000  1995.000000
# max    2018.000000  2017.000000  2017.000000

# %%
sns.kdeplot(x = 'YearBuilt', data = new_data, hue = 'Type', palette = 'rocket')
plt.show()

# %% [markdown]
# -- Type 'h'(house,cottage,villa, semi,terrace) sells more

# %% [markdown]
# * *Which Region has the maximum price?*

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x="Regionname",y="Price",data=new_data,)
sns.set_style("ticks")
plt.show()

# %% [markdown]
# * *Scatter plot for Landsize and Regionname*

# %%
fig, ax = plt.subplots(figsize=(6,6))
ax.scatter(new_data['Landsize'], new_data['Regionname'])
ax.set_xlabel('Landsize')
ax.set_ylabel('Regionname')
plt.show()

# %% [markdown]
# * *Data Correlation*

# %%
selected_columns=new_data[["YearBuilt","BuildingArea","Landsize","Price"]]
plt.figure(figsize=(8,6))
sns.heatmap(selected_columns.corr(), annot=True, cmap='BrBG', cbar_kws={'label': 'Correlation'})
plt.show()

# %% [markdown]
# * *Number of rooms available*

# %%
council_area = new_data['Rooms'].unique()
council_area
# Out:
# array([ 2,  3,  4,  1,  6,  5,  8,  7, 10], dtype=int64)

# %%
council_area_count = new_data['Rooms'].value_counts()
council_name = council_area_count.index
council_value = council_area_count.values
plt.figure(figsize=(10,8))
percentage = (council_value/council_value.sum())*100
plt.pie(x = council_value, labels = council_name, autopct='%1.1f%%')
plt.show()
